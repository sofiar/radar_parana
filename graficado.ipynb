# %%
# %matplotlib inline
print __doc__

import numpy
import pyart
import matplotlib.pyplot as plt
import netCDF4

#import pyart.io as io
#import pyart.correct as correct
#from pyart.correct import dealias_fourdd
# Out:
# Automatically created module for IPython interactive environment

# %%
##cargamos los datos y los leemos con py art
##file ya esta convertido a cr/radial
file="/home/sofia/Documents/ejemplo/test/20141226/cfrad.20141226_180433.000_to_20141226_180729.999_INTA_Par_v1_SUR.nc"
radar = pyart.io.read_cfradial(file)

# %%
##Grafico ppi de los datos PPI de la primera elevacion
xlims=[-150,150]
ylims=[-150,150]

tilt=0  #elevacion
display = pyart.graph.RadarDisplay(radar)
fig = plt.figure(figsize=(6, 5))
display.plot_ppi('dBZ', tilt,
                 colorbar_label='',
                 axislabels_flag=False,vmin=-25,vmax=70)
display.set_limits(xlims,ylims)
plt.show()

# %%
display = pyart.graph.RadarDisplay(radar)
fig = plt.figure()
ax = fig.add_subplot(111)
display.plot('dBZ', 0, vmin=-32, vmax=64.)
display.plot_range_rings([10, 20, 30, 40])
display.plot_cross_hair(5.)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-26-9c79d87d2e99> in <module>()
# ----> 1 display = pyart.graph.RadarDisplay(radar)
#       2 fig = plt.figure()
#       3 ax = fig.add_subplot(111)
#       4 display.plot('dBZ', 0, vmin=-32, vmax=64.)
#       5 display.plot_range_rings([10, 20, 30, 40])
#
# AttributeError: 'module' object has no attribute 'graph'

# %%
##probamos el algoritmo de de-aliasing de py art


dealias_data = correct.dealias_fourdd(
    radar, sounding_heights=height * 1000.0, sounding_wind_speeds=speed,
    sounding_wind_direction=direction)
radar.add_field('corrected_velocity', dealias_data)

pyart.correct.dealias_fourdd
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-20-24d8b93ca9e5> in <module>()
#       1 ##probamos el algoritmo de de-aliasing de py art
# ----> 2 dealias_data = correct.dealias_fourdd(
#       3     radar, sounding_heights=height * 1000.0, sounding_wind_speeds=speed,
#       4     sounding_wind_direction=direction)
#       5 radar.add_field('corrected_velocity', dealias_data)
#
# AttributeError: 'module' object has no attribute 'dealias_fourdd'

# %%
pyart
# Out:
# <module 'pyart' from '/usr/local/lib/python2.7/dist-packages/pyart/__init__.pyc'>

# %%
pyart.io
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-3772dee7a5ee> in <module>()
# ----> 1 pyart.io
#
# AttributeError: 'module' object has no attribute 'io'

# %%
# %matplotlib inline
# %load_ext rmagic
print __doc__
import numpy as np
import pyart
import matplotlib.pyplot as plt
import netCDF4
import copy
import scipy.ndimage as nd
import numpy.ma as ma
from IPython.display import Latex
# Out:
# Automatically created module for IPython interactive environment
# /home/sofia/anaconda/lib/python2.7/site-packages/IPython/extensions/rmagic.py:693: UserWarning: The rmagic extension in IPython is deprecated in favour of rpy2.ipython. If available, that will be loaded instead.
# http://rpy.sourceforge.net/
#   warnings.warn("The rmagic extension in IPython is deprecated in favour of "

# %% [markdown]
# ###Caso del 04 de Marzo 2010 Clutter

# %%
file1='/home/sofia/radar_parana/DATOS/CFRad/20100304/120/cfrad.20100304_083346.000_to_20100304_083734.000_INTA_Par_v44_SUR.nc' 
file2='/home/sofia/radar_parana/DATOS/CFRad/20100304/120/cfrad.20100304_120346.000_to_20100304_120735.000_INTA_Par_v62_SUR.nc' 
file3='/home/sofia/radar_parana/DATOS/CFRad/20100304/120/cfrad.20100304_164347.000_to_20100304_164736.000_INTA_Par_v89_SUR.nc'
file4='/home/sofia/radar_parana/DATOS/CFRad/20100304/120/cfrad.20100304_195345.000_to_20100304_195730.778_INTA_Par_v108_SUR.nc'
file5='/home/sofia/radar_parana/DATOS/CFRad/20100304/120/cfrad.20100304_144346.000_to_20100304_144734.000_INTA_Par_v77_SUR.nc'
file6='/home/sofia/radar_parana/DATOS/CFRad/20100304/120/cfrad.20100304_222345.000_to_20100304_222732.973_INTA_Par_v122_SUR.nc'


radar1=pyart.io.read_cfradial(file1)
radar2=pyart.io.read_cfradial(file2)
radar3=pyart.io.read_cfradial(file3)
radar4=pyart.io.read_cfradial(file4)
radar5=pyart.io.read_cfradial(file5)
radar6=pyart.io.read_cfradial(file6)

# %%
display1 = pyart.graph.RadarMapDisplay(radar1)
display2 = pyart.graph.RadarMapDisplay(radar2)
display3 = pyart.graph.RadarMapDisplay(radar3)
display4 = pyart.graph.RadarMapDisplay(radar4)
display5 = pyart.graph.RadarMapDisplay(radar5)
display6 = pyart.graph.RadarMapDisplay(radar6)

f = plt.figure(figsize = [13,9])

plt.subplot(2, 3, 1) 
display1.plot_ppi('dBZ',vmin=-25,vmax=75)
plt.subplot(2, 3, 2) 
display2.plot_ppi('dBZ',vmin=-25,vmax=75)
plt.subplot(2, 3, 3) 
display3.plot_ppi('dBZ',vmin=-25,vmax=75) 
plt.subplot(2, 3, 4) 
display4.plot_ppi('dBZ',vmin=-25,vmax=75)
plt.subplot(2, 3, 5) 
display5.plot_ppi('dBZ',vmin=-25,vmax=75)
plt.subplot(2, 3, 6) 
display6.plot_ppi('dBZ',vmin=-25,vmax=75)

# %% [markdown]
# ###Caso 01 de Marzo de 2010

# %%
file1='/home/sofia/radar_parana/DATOS/CFRad/20100301/120/cfrad.20100301_060347.000_to_20100301_060735.000_INTA_Par_v33_SUR.nc' 
file2='/home/sofia/radar_parana/DATOS/CFRad/20100301/120/cfrad.20100301_041347.000_to_20100301_041736.000_INTA_Par_v23_SUR.nc' 
file3='/home/sofia/radar_parana/DATOS/CFRad/20100301/120/cfrad.20100301_052348.000_to_20100301_052735.001_INTA_Par_v29_SUR.nc'
file4='/home/sofia/radar_parana/DATOS/CFRad/20100301/120/cfrad.20100301_093346.000_to_20100301_093732.778_INTA_Par_v52_SUR.nc'
file5='/home/sofia/radar_parana/DATOS/CFRad/20100301/120/cfrad.20100301_100346.000_to_20100301_100734.000_INTA_Par_v54_SUR.nc'
file6='/home/sofia/radar_parana/DATOS/CFRad/20100301/120/cfrad.20100301_093346.000_to_20100301_093732.778_INTA_Par_v52_SUR.nc'


radar1=pyart.io.read_cfradial(file1)
radar2=pyart.io.read_cfradial(file2)
radar3=pyart.io.read_cfradial(file3)
radar4=pyart.io.read_cfradial(file4)
radar5=pyart.io.read_cfradial(file5)
radar6=pyart.io.read_cfradial(file6)

# %%
display1 = pyart.graph.RadarMapDisplay(radar1)
display2 = pyart.graph.RadarMapDisplay(radar2)
display3 = pyart.graph.RadarMapDisplay(radar3)
display4 = pyart.graph.RadarMapDisplay(radar4)
display5 = pyart.graph.RadarMapDisplay(radar5)
display6 = pyart.graph.RadarMapDisplay(radar6)

f = plt.figure(figsize = [15,9])

plt.subplot(2, 3, 1) 
display1.plot_ppi('dBZ',vmin=-25,vmax=75)
plt.subplot(2, 3, 2) 
display2.plot_ppi('dBZ',vmin=-25,vmax=75)
plt.subplot(2, 3, 3) 
display3.plot_ppi('dBZ',vmin=-25,vmax=75) 
plt.subplot(2, 3, 4) 
display4.plot_ppi('dBZ',vmin=-25,vmax=75) ##pajaros??
plt.subplot(2, 3, 5) 
display5.plot_ppi('dBZ',vmin=-25,vmax=75)
plt.subplot(2, 3, 6) 
display6.plot_ppi('dBZ',vmin=-25,vmax=75)

# %% [markdown]
# ###Caso de 02 de Marzo de 2010
# ###Rango de 240

# %%
file1='/home/sofia/radar_parana/DATOS/CFRad/20100302/240/cfrad.20100302_005002.000_to_20100302_005343.000_INTA_Par_v6_SUR.nc' 
file2='/home/sofia/radar_parana/DATOS/CFRad/20100302/240/cfrad.20100302_074002.000_to_20100302_074342.000_INTA_Par_v46_SUR.nc' 
file3='/home/sofia/radar_parana/DATOS/CFRad/20100302/240/cfrad.20100302_155002.000_to_20100302_155342.999_INTA_Par_v95_SUR.nc'
file4='/home/sofia/radar_parana/DATOS/CFRad/20100302/240/cfrad.20100302_130002.000_to_20100302_130343.001_INTA_Par_v78_SUR.nc'
file5='/home/sofia/radar_parana/DATOS/CFRad/20100302/240/cfrad.20100302_190002.000_to_20100302_190341.999_INTA_Par_v114_SUR.nc'
file6='/home/sofia/radar_parana/DATOS/CFRad/20100302/240/cfrad.20100302_202003.000_to_20100302_202342.000_INTA_Par_v121_SUR.nc'


radar1=pyart.io.read_cfradial(file1)
radar2=pyart.io.read_cfradial(file2)
radar3=pyart.io.read_cfradial(file3)
radar4=pyart.io.read_cfradial(file4)
radar5=pyart.io.read_cfradial(file5)
radar6=pyart.io.read_cfradial(file6)

# %%
display1 = pyart.graph.RadarMapDisplay(radar1)
display2 = pyart.graph.RadarMapDisplay(radar2)
display3 = pyart.graph.RadarMapDisplay(radar3)
display4 = pyart.graph.RadarMapDisplay(radar4)
display5 = pyart.graph.RadarMapDisplay(radar5)
display6 = pyart.graph.RadarMapDisplay(radar6)

f = plt.figure(figsize = [16,11])

plt.subplot(2, 3, 1) 
display1.plot_ppi('dBZ',vmin=-25,vmax=75)
plt.subplot(2, 3, 2) 
display2.plot_ppi('dBZ',vmin=-25,vmax=75)
plt.subplot(2, 3, 3) 
display3.plot_ppi('dBZ',vmin=-25,vmax=75) 
plt.subplot(2, 3, 4) 
display4.plot_ppi('dBZ',vmin=-25,vmax=75) 
plt.subplot(2, 3, 5) 
display5.plot_ppi('dBZ',vmin=-25,vmax=75)
plt.subplot(2, 3, 6) 
display6.plot_ppi('dBZ',vmin=-25,vmax=75)

# %% [markdown]
# ####Las dos primeras, pájaros??
# ####Las dos segundas, anaprop??
# ####Las utlimas lluevia ???

# %% [markdown]
# ###Caso de 06 de Marzo

# %%
file1='/home/sofia/radar_parana/DATOS/CFRad/20100306/120/cfrad.20100306_020347.000_to_20100306_020735.999_INTA_Par_v11_SUR.nc' 
file2='/home/sofia/radar_parana/DATOS/CFRad/20100306/120/cfrad.20100306_061350.000_to_20100306_061738.000_INTA_Par_v32_SUR.nc' 
file3='/home/sofia/radar_parana/DATOS/CFRad/20100306/120/cfrad.20100306_093348.000_to_20100306_093735.000_INTA_Par_v50_SUR.nc'
file4='/home/sofia/radar_parana/DATOS/CFRad/20100306/120/cfrad.20100306_130346.000_to_20100306_130730.555_INTA_Par_v71_SUR.nc'
file5='/home/sofia/radar_parana/DATOS/CFRad/20100306/120/cfrad.20100306_181349.000_to_20100306_181738.001_INTA_Par_v99_SUR.nc'
file6='/home/sofia/radar_parana/DATOS/CFRad/20100306/120/cfrad.20100306_215347.000_to_20100306_215734.999_INTA_Par_v118_SUR.nc'


radar1=pyart.io.read_cfradial(file1)
radar2=pyart.io.read_cfradial(file2)
radar3=pyart.io.read_cfradial(file3)
radar4=pyart.io.read_cfradial(file4)
radar5=pyart.io.read_cfradial(file5)
radar6=pyart.io.read_cfradial(file6)

# %%
display1 = pyart.graph.RadarMapDisplay(radar1)
display2 = pyart.graph.RadarMapDisplay(radar2)
display3 = pyart.graph.RadarMapDisplay(radar3)
display4 = pyart.graph.RadarMapDisplay(radar4)
display5 = pyart.graph.RadarMapDisplay(radar5)
display6 = pyart.graph.RadarMapDisplay(radar6)

f = plt.figure(figsize = [16,11])

plt.subplot(2, 3, 1) 
display1.plot_ppi('dBZ',vmin=-25,vmax=75)
plt.subplot(2, 3, 2) 
display2.plot_ppi('dBZ',vmin=-25,vmax=75)
plt.subplot(2, 3, 3) 
display3.plot_ppi('dBZ',vmin=-25,vmax=75) 
plt.subplot(2, 3, 4) 
display4.plot_ppi('dBZ',vmin=-25,vmax=75) 
plt.subplot(2, 3, 5) 
display5.plot_ppi('dBZ',vmin=-25,vmax=75)
plt.subplot(2, 3, 6) 
display6.plot_ppi('dBZ',vmin=-25,vmax=75)

# %% [markdown]
# ###Caso del 07 de Marzo de 2010

# %%
file1='/home/sofia/radar_parana/DATOS/CFRad/20100307/120/cfrad.20100307_013346.000_to_20100307_013732.556_INTA_Par_v9_SUR.nc' 
file2='/home/sofia/radar_parana/DATOS/CFRad/20100307/120/cfrad.20100307_085346.000_to_20100307_085708.000_INTA_Par_v48_SUR.nc' 
file3='/home/sofia/radar_parana/DATOS/CFRad/20100307/120/cfrad.20100307_105346.000_to_20100307_105733.000_INTA_Par_v59_SUR.nc'
file4='/home/sofia/radar_parana/DATOS/CFRad/20100307/120/cfrad.20100307_154346.000_to_20100307_154732.977_INTA_Par_v86_SUR.nc'
file5='/home/sofia/radar_parana/DATOS/CFRad/20100307/120/cfrad.20100307_191349.000_to_20100307_191737.000_INTA_Par_v105_SUR.nc'
file6='/home/sofia/radar_parana/DATOS/CFRad/20100307/120/cfrad.20100307_225346.000_to_20100307_225735.000_INTA_Par_v126_SUR.nc'


radar1=pyart.io.read_cfradial(file1)
radar2=pyart.io.read_cfradial(file2)
radar3=pyart.io.read_cfradial(file3)
radar4=pyart.io.read_cfradial(file4)
radar5=pyart.io.read_cfradial(file5)
radar6=pyart.io.read_cfradial(file6)

# %%
display1 = pyart.graph.RadarMapDisplay(radar1)
display2 = pyart.graph.RadarMapDisplay(radar2)
display3 = pyart.graph.RadarMapDisplay(radar3)
display4 = pyart.graph.RadarMapDisplay(radar4)
display5 = pyart.graph.RadarMapDisplay(radar5)
display6 = pyart.graph.RadarMapDisplay(radar6)

f = plt.figure(figsize = [16,11])

plt.subplot(2, 3, 1) 
display1.plot_ppi('dBZ',vmin=-25,vmax=75)
plt.subplot(2, 3, 2) 
display2.plot_ppi('dBZ',vmin=-25,vmax=75)
plt.subplot(2, 3, 3) 
display3.plot_ppi('dBZ',vmin=-25,vmax=75) 
plt.subplot(2, 3, 4) 
display4.plot_ppi('dBZ',vmin=-25,vmax=75) 
plt.subplot(2, 3, 5) 
display5.plot_ppi('dBZ',vmin=-25,vmax=75)
plt.subplot(2, 3, 6) 
display6.plot_ppi('dBZ',vmin=-25,vmax=75)

# %% [markdown]
# ###Caso 23 de Marzo (no tenego las variables polarimetricas, estan??)

# %%
file1='/home/sofia/radar_parana/DATOS/CFRad/20100323_dbz_V/cfrad.20100323_063003.000_to_20100323_063344.001_INTA_Par_v77_SUR.nc'
file2= '/home/sofia/radar_parana/DATOS/CFRad/20100323_dbz_V/cfrad.20100323_100348.000_to_20100323_100735.000_INTA_Par_v120_SUR.nc'
file3='/home/sofia/radar_parana/DATOS/CFRad/20100323_dbz_V/cfrad.20100323_113348.000_to_20100323_113734.000_INTA_Par_v138_SUR.nc'
file4='/home/sofia/radar_parana/DATOS/CFRad/20100323_dbz_V/cfrad.20100323_151008.000_to_20100323_151348.001_INTA_Par_v180_SUR.nc'
file5='/home/sofia/radar_parana/DATOS/CFRad/20100323_dbz_V/cfrad.20100323_173002.000_to_20100323_173342.998_INTA_Par_v208_SUR.nc'
file6='/home/sofia/radar_parana/DATOS/CFRad/20100323_dbz_V/cfrad.20100323_220003.000_to_20100323_220343.999_INTA_Par_v260_SUR.nc'

radar1=pyart.io.read_cfradial(file1)
radar2=pyart.io.read_cfradial(file2)
radar3=pyart.io.read_cfradial(file3)
radar4=pyart.io.read_cfradial(file4)
radar5=pyart.io.read_cfradial(file5)
radar6=pyart.io.read_cfradial(file6)

# %%
display1 = pyart.graph.RadarMapDisplay(radar1)
display2 = pyart.graph.RadarMapDisplay(radar2)
display3 = pyart.graph.RadarMapDisplay(radar3)
display4 = pyart.graph.RadarMapDisplay(radar4)
display5 = pyart.graph.RadarMapDisplay(radar5)
display6 = pyart.graph.RadarMapDisplay(radar6)

f = plt.figure(figsize = [16,11])

plt.subplot(2, 3, 1) 
display1.plot_ppi('dBZ',vmin=-25,vmax=75)
plt.subplot(2, 3, 2) 
display2.plot_ppi('dBZ',vmin=-25,vmax=75)
plt.subplot(2, 3, 3) 
display3.plot_ppi('dBZ',vmin=-25,vmax=75) 
plt.subplot(2, 3, 4) 
display4.plot_ppi('dBZ',vmin=-25,vmax=75) 
plt.subplot(2, 3, 5) 
display5.plot_ppi('dBZ',vmin=-25,vmax=75)
plt.subplot(2, 3, 6) 
display6.plot_ppi('dBZ',vmin=-25,vmax=75)
